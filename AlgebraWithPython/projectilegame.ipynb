# %%
import matplotlib.pyplot as plt
import numpy as np
import random as rnd
from matplotlib.animation import FuncAnimation
from IPython import display

def animate(i,a,b):
    points = 10*i
    x = np.linspace(0,i,points)
    y = a * x**2 + b * x 
    ax.plot(x,y)

  
xmin = 0
xmax = 80
ymin = 0
ymax = 1000
a = -4.9
binput = float(input('Initial velocity in m/s'))

fig, ax = plt.subplots()

plt.axis([xmin,xmax,ymin,ymax]) # * window size
plt.plot([xmin,xmax],[0,0],'black') # * black x axis
plt.plot([0,0],[ymin,ymax], 'black') # * black y axis
ax.grid(True)
ax.set_title('Projectile Game')

# * Build wall
xwall = rnd.randint(int(xmax/4), xmax)
hwall = rnd.randint(int(ymax/4), int(ymax*3/4))

print(f'A toy rocket has to clear a wall {xwall} meters away')
print(f'Height of the wall : {hwall} meters')
plt.plot([xwall,xwall],[0,hwall],'b')

# * First equation set equal to zero, ready to solve
b = xwall * -(2*a) 
print(b)

# Create the animation with parameters
ani = FuncAnimation(fig, animate, fargs=(a,b),frames=np.arange(0, xmax))

# Display the animation
display(ani.to_jshtml())
# Out:
# A toy rocket has to clear a wall 80 meters away
# Height of the wall : 402 meters
# 784.0
# 0 -4.9 784.0
# 0 -4.9 784.0
# 1 -4.9 784.0
# 2 -4.9 784.0
# 3 -4.9 784.0
# 4 -4.9 784.0
# 5 -4.9 784.0
# 6 -4.9 784.0
# 7 -4.9 784.0
# 8 -4.9 784.0
# 9 -4.9 784.0
# 10 -4.9 784.0
# 11 -4.9 784.0
# 12 -4.9 784.0
# 13 -4.9 784.0
# 14 -4.9 784.0
# 15 -4.9 784.0
# 16 -4.9 784.0
# 17 -4.9 784.0
# 18 -4.9 784.0
# 19 -4.9 784.0
# 20 -4.9 784.0
# 21 -4.9 784.0
# 22 -4.9 784.0
# 23 -4.9 784.0
# 24 -4.9 784.0
# 25 -4.9 784.0
# 26 -4.9 784.0
# 27 -4.9 784.0
# 28 -4.9 784.0
# 29 -4.9 784.0
# 30 -4.9 784.0
# 31 -4.9 784.0
# 32 -4.9 784.0
# 33 -4.9 784.0
# 34 -4.9 784.0
# 35 -4.9 784.0
# 36 -4.9 784.0
# 37 -4.9 784.0
# 38 -4.9 784.0
# 39 -4.9 784.0
# 40 -4.9 784.0
# 41 -4.9 784.0
# 42 -4.9 784.0
# 43 -4.9 784.0
# 44 -4.9 784.0
# 45 -4.9 784.0
# 46 -4.9 784.0
# 47 -4.9 784.0
# 48 -4.9 784.0
# 49 -4.9 784.0
# 50 -4.9 784.0
# 51 -4.9 784.0
# 52 -4.9 784.0
# 53 -4.9 784.0
# 54 -4.9 784.0
# 55 -4.9 784.0
# 56 -4.9 784.0
# 57 -4.9 784.0
# 58 -4.9 784.0
# 59 -4.9 784.0
# 60 -4.9 784.0
# 61 -4.9 784.0
# 62 -4.9 784.0
# 63 -4.9 784.0
# 64 -4.9 784.0
# 65 -4.9 784.0
# 66 -4.9 784.0
# 67 -4.9 784.0
# 68 -4.9 784.0
# 69 -4.9 784.0
# 70 -4.9 784.0
# 71 -4.9 784.0
# 72 -4.9 784.0
# 73 -4.9 784.0
# 74 -4.9 784.0
# 75 -4.9 784.0
# 76 -4.9 784.0
# 77 -4.9 784.0
# 78 -4.9 784.0
# 79 -4.9 784.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 46
#      43 ani = FuncAnimation(fig, animate, fargs=(a,b),frames=np.arange(0, xmax))
#      45 # Display the animation
# ---> 46 display(ani.to_jshtml())
#
# TypeError: 'module' object is not callable
# 0 -4.9 784.0
